# %% [markdown]
# # Playing CSV

# %%
# !pip install pandas
import pandas as pd

# %%
df = pd.read_csv('countries_with_missing_blood_group_values.csv')

# %%
df
# Out:
#   Country/Dependency   Population      O+      A+      B+    AB+      O-  \
# 0              Egypt  104,124,440  36.44%  33.94%  20.96%  8.65%     NaN
# 1           Mongolia    3,198,913  36.40%  29.20%   8.10%    NaN  13.30%
#
#       A-     B-    AB-
# 0    NaN    NaN    NaN
# 1  8.00%  2.00%  0.01%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country/Dependency  2 non-null      object
#  1   Population          2 non-null      object
#  2   O+                  2 non-null      object
#  3   A+                  2 non-null      object
#  4   B+                  2 non-null      object
#  5   AB+                 1 non-null      object
#  6   O-                  1 non-null      object
#  7   A-                  1 non-null      object
#  8   B-                  1 non-null      object
#  9   AB-                 1 non-null      object
# dtypes: object(10)
# memory usage: 292.0+ bytes

# %% [markdown]
# # Playing JSON

# %%
pd.read_json('https://dummyjson.com/quotes')
# Out:
#                                                quotes  total  skip  limit
# 0   {'id': 1, 'quote': 'Your heart is the size of ...   1454     0     30
# 1   {'id': 2, 'quote': 'The Bay of Bengal is hit f...   1454     0     30
# 2   {'id': 3, 'quote': 'Thinking is the capital, E...   1454     0     30
# 3   {'id': 4, 'quote': 'If You Can'T Make It Good,...   1454     0     30
# 4   {'id': 5, 'quote': 'Heart be brave. If you can...   1454     0     30
# 5   {'id': 6, 'quote': 'It is bad for a young man ...   1454     0     30
# 6   {'id': 7, 'quote': 'If You Are Out To Describe...   1454     0     30
# 7   {'id': 8, 'quote': 'O man you are busy working...   1454     0     30
# 8   {'id': 9, 'quote': 'While children are struggl...   1454     0     30
# 9   {'id': 10, 'quote': 'These Capitalists General...   1454     0     30
# 10  {'id': 11, 'quote': 'I Don'T Believe In Failur...   1454     0     30
# 11  {'id': 12, 'quote': 'Do not get elated at any ...   1454     0     30
# ...
