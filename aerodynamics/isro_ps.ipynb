# %%
# !pip install astropy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 16.6 MB/s eta 0:00:001m17.7 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.7/738.7 kB 14.1 MB/s eta 0:00:00
# ...

# %%
from astropy.io import fits

# %%
fits_image_path = 'fits_image.fits'
with fits.open(fits_image_path) as hdul:
    hdul.info()
# Out:
# Filename: fits_image.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       5   ()
#   1  SPECTRUM      1 BinTableHDU     73   2048R x 2C   [1I, 1E]
