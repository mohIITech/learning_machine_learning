# %%
# !pip install neuralfoil --timeout=300
# Out:
# ...
#   Using cached neuralfoil-0.3.2-py3-none-any.whl.metadata (33 kB)
# ...
#   Using cached aerosandbox-4.2.8-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached casadi-3.7.2-cp312-none-manylinux2014_x86_64.whl.metadata (2.2 kB)
# ...
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached neuralfoil-0.3.2-py3-none-any.whl (7.6 MB)
# Using cached aerosandbox-4.2.8-py3-none-any.whl (6.9 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 MB 548.3 kB/s eta 0:00:00m eta 0:00:010:00:04
# ...

# %%
# !pip install aerosandbox --timeout=300

# %%
import aerosandbox as asb

# %%
asb.docs()
# Out:
# Opening in existing browser session.
