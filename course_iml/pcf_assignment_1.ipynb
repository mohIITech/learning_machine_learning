# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-100, 100, 1)
y = 0.6 * np.exp(-0.5 * x) + 0.35 * np.exp(-2 * x**0.6) + 0.05 * np.exp(-0.075 * x) * np.cos(0.5 * x)

plt.plot(x, y)
# Out:
# /tmp/ipykernel_131232/3796956558.py:5: RuntimeWarning: invalid value encountered in power
#   y = 0.6 * np.exp(-0.5 * x) + 0.35 * np.exp(-2 * x**0.6) + 0.05 * np.exp(-0.075 * x) * np.cos(0.5 * x)
